# %%
from huggingface_hub import HfApi

# %%
api = HfApi()
repo_id = "tigreraph/ecoflash-dataset"   # REEMPLAZA con tu usuario

api.upload_folder(
    folder_path="dataset",               # carpeta local
    repo_id=repo_id,
    repo_type="dataset"
)

print("✅ Dataset subido correctamente a HuggingFace.")
# Out:
# It seems you are trying to upload a large folder at once. This might take some time and then fail if the folder is too large. For such cases, it is recommended to upload in smaller batches or to use `HfApi().upload_large_folder(...)`/`hf upload-large-folder` instead. For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/upload#upload-a-large-folder.
# Processing Files (3063 / 3063): 100%|██████████| 79.6MB / 79.6MB, 10.1MB/s
# New Data Upload: |          |  0.00B /  0.00B,  0.00B/s
# No files have been modified since last commit. Skipping to prevent empty commit.
# ✅ Dataset subido correctamente a HuggingFace.
